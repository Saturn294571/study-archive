# %%
# !pip install llist
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for llist: filename=llist-0.7.1-cp310-cp310-linux_x86_64.whl size=74084 sha256=fc1b2214c0182bf0ccaf9a5a8d855b731bd00a49eb475b6b48ff7ae3f5979842
#   Stored in directory: /root/.cache/pip/wheels/e9/91/41/252becb26acf296e14913e0ee13940295bc475be57aed9bb2e
# Successfully built llist
# ...

# %%
# !pip install llist
import llist
from llist import dllist
lst = dllist(['first', 'second', 'third'])

# %%
curNode = lst.nodeat(0)
print(lst.first.value)
# Out:
# first

# %%
curNode = lst.nodeat(1)
print(curNode.value)
curNode = lst.nodeat(2)
print(curNode.value)
# Out:
# second
# third
