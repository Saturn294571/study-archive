# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras import datasets 
from tensorflow.keras.utils import to_categorical

# %%
(train_images, _), (test_images, _) = datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# 픽셀 값을 0~1 사이로 정규화합니다.
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
noise_factor = 0.2
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
test_images_noisy = test_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=test_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)
test_images_noisy = np.clip(test_images_noisy, 0., 1.)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2), padding='same'))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2), padding='same'))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.UpSampling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.UpSampling2D((2, 2)))
model.add(layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same'))

model.summary()

model.compile(optimizer='adadelta', loss='binary_crossentropy')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_images_noisy, train_images,
                epochs=100,
                batch_size=128,
                shuffle=True,
                verbose = 2)

decoded_imgs = model.predict(test_images_noisy)
# Out:
# Epoch 1/100
# 469/469 - 13s - loss: 0.6810 - 13s/epoch - 28ms/step
# Epoch 2/100
# 469/469 - 2s - loss: 0.6615 - 2s/epoch - 5ms/step
# Epoch 3/100
# 469/469 - 2s - loss: 0.6247 - 2s/epoch - 5ms/step
# Epoch 4/100
# 469/469 - 2s - loss: 0.5712 - 2s/epoch - 5ms/step
# Epoch 5/100
# 469/469 - 2s - loss: 0.5378 - 2s/epoch - 5ms/step
# Epoch 6/100
# 469/469 - 2s - loss: 0.5228 - 2s/epoch - 5ms/step
# Epoch 7/100
# 469/469 - 2s - loss: 0.5088 - 2s/epoch - 5ms/step
# Epoch 8/100
# 469/469 - 2s - loss: 0.4934 - 2s/epoch - 5ms/step
# Epoch 9/100
# 469/469 - 3s - loss: 0.4754 - 3s/epoch - 6ms/step
# Epoch 10/100
# 469/469 - 2s - loss: 0.4537 - 2s/epoch - 5ms/step
# Epoch 11/100
# 469/469 - 2s - loss: 0.4267 - 2s/epoch - 5ms/step
# Epoch 12/100
# 469/469 - 2s - loss: 0.3935 - 2s/epoch - 5ms/step
# Epoch 13/100
# 469/469 - 2s - loss: 0.3547 - 2s/epoch - 5ms/step
# Epoch 14/100
# 469/469 - 2s - loss: 0.3134 - 2s/epoch - 5ms/step
# Epoch 15/100
# 469/469 - 2s - loss: 0.2750 - 2s/epoch - 5ms/step
# Epoch 16/100
# 469/469 - 2s - loss: 0.2435 - 2s/epoch - 5ms/step
# Epoch 17/100
# 469/469 - 2s - loss: 0.2212 - 2s/epoch - 5ms/step
# Epoch 18/100
# 469/469 - 2s - loss: 0.2057 - 2s/epoch - 5ms/step
# Epoch 19/100
# 469/469 - 2s - loss: 0.1946 - 2s/epoch - 5ms/step
# Epoch 20/100
# 469/469 - 2s - loss: 0.1865 - 2s/epoch - 5ms/step
# Epoch 21/100
# 469/469 - 2s - loss: 0.1806 - 2s/epoch - 5ms/step
# Epoch 22/100
# 469/469 - 2s - loss: 0.1760 - 2s/epoch - 5ms/step
# Epoch 23/100
# 469/469 - 2s - loss: 0.1724 - 2s/epoch - 5ms/step
# Epoch 24/100
# 469/469 - 2s - loss: 0.1692 - 2s/epoch - 5ms/step
# Epoch 25/100
# 469/469 - 2s - loss: 0.1666 - 2s/epoch - 5ms/step
# Epoch 26/100
# 469/469 - 2s - loss: 0.1642 - 2s/epoch - 5ms/step
# Epoch 27/100
# 469/469 - 2s - loss: 0.1621 - 2s/epoch - 5ms/step
# Epoch 28/100
# 469/469 - 2s - loss: 0.1601 - 2s/epoch - 5ms/step
# Epoch 29/100
# 469/469 - 2s - loss: 0.1583 - 2s/epoch - 5ms/step
# Epoch 30/100
# 469/469 - 2s - loss: 0.1567 - 2s/epoch - 5ms/step
# Epoch 31/100
# 469/469 - 2s - loss: 0.1552 - 2s/epoch - 5ms/step
# Epoch 32/100
# 469/469 - 2s - loss: 0.1538 - 2s/epoch - 5ms/step
# Epoch 33/100
# 469/469 - 2s - loss: 0.1524 - 2s/epoch - 5ms/step
# Epoch 34/100
# 469/469 - 2s - loss: 0.1512 - 2s/epoch - 5ms/step
# Epoch 35/100
# 469/469 - 2s - loss: 0.1500 - 2s/epoch - 5ms/step
# Epoch 36/100
# 469/469 - 2s - loss: 0.1489 - 2s/epoch - 5ms/step
# Epoch 37/100
# 469/469 - 3s - loss: 0.1478 - 3s/epoch - 6ms/step
# Epoch 38/100
# 469/469 - 2s - loss: 0.1468 - 2s/epoch - 5ms/step
# Epoch 39/100
# 469/469 - 2s - loss: 0.1459 - 2s/epoch - 5ms/step
# Epoch 40/100
# 469/469 - 2s - loss: 0.1449 - 2s/epoch - 5ms/step
# Epoch 41/100
# 469/469 - 2s - loss: 0.1440 - 2s/epoch - 5ms/step
# Epoch 42/100
# 469/469 - 2s - loss: 0.1431 - 2s/epoch - 5ms/step
# Epoch 43/100
# 469/469 - 2s - loss: 0.1422 - 2s/epoch - 5ms/step
# Epoch 44/100
# 469/469 - 2s - loss: 0.1413 - 2s/epoch - 5ms/step
# Epoch 45/100
# 469/469 - 2s - loss: 0.1404 - 2s/epoch - 5ms/step
# Epoch 46/100
# 469/469 - 2s - loss: 0.1396 - 2s/epoch - 5ms/step
# Epoch 47/100
# 469/469 - 2s - loss: 0.1388 - 2s/epoch - 5ms/step
# Epoch 48/100
# 469/469 - 2s - loss: 0.1379 - 2s/epoch - 5ms/step
# Epoch 49/100
# 469/469 - 2s - loss: 0.1371 - 2s/epoch - 5ms/step
# Epoch 50/100
# 469/469 - 2s - loss: 0.1363 - 2s/epoch - 5ms/step
# Epoch 51/100
# 469/469 - 2s - loss: 0.1355 - 2s/epoch - 5ms/step
# Epoch 52/100
# 469/469 - 2s - loss: 0.1348 - 2s/epoch - 5ms/step
# Epoch 53/100
# 469/469 - 2s - loss: 0.1340 - 2s/epoch - 5ms/step
# Epoch 54/100
# 469/469 - 2s - loss: 0.1333 - 2s/epoch - 5ms/step
# Epoch 55/100
# 469/469 - 2s - loss: 0.1325 - 2s/epoch - 5ms/step
# Epoch 56/100
# 469/469 - 2s - loss: 0.1318 - 2s/epoch - 5ms/step
# Epoch 57/100
# 469/469 - 2s - loss: 0.1311 - 2s/epoch - 5ms/step
# Epoch 58/100
# 469/469 - 2s - loss: 0.1303 - 2s/epoch - 5ms/step
# Epoch 59/100
# 469/469 - 2s - loss: 0.1296 - 2s/epoch - 5ms/step
# Epoch 60/100
# 469/469 - 2s - loss: 0.1289 - 2s/epoch - 5ms/step
# Epoch 61/100
# 469/469 - 2s - loss: 0.1282 - 2s/epoch - 5ms/step
# Epoch 62/100
# 469/469 - 2s - loss: 0.1276 - 2s/epoch - 5ms/step
# Epoch 63/100
# 469/469 - 2s - loss: 0.1269 - 2s/epoch - 5ms/step
# Epoch 64/100
# 469/469 - 2s - loss: 0.1263 - 2s/epoch - 5ms/step
# Epoch 65/100
# 469/469 - 2s - loss: 0.1256 - 2s/epoch - 5ms/step
# Epoch 66/100
# 469/469 - 2s - loss: 0.1250 - 2s/epoch - 5ms/step
# Epoch 67/100
# 469/469 - 2s - loss: 0.1244 - 2s/epoch - 5ms/step
# Epoch 68/100
# 469/469 - 2s - loss: 0.1238 - 2s/epoch - 5ms/step
# Epoch 69/100
# 469/469 - 2s - loss: 0.1232 - 2s/epoch - 5ms/step
# Epoch 70/100
# 469/469 - 2s - loss: 0.1227 - 2s/epoch - 5ms/step
# Epoch 71/100
# 469/469 - 2s - loss: 0.1221 - 2s/epoch - 5ms/step
# Epoch 72/100
# 469/469 - 2s - loss: 0.1216 - 2s/epoch - 5ms/step
# Epoch 73/100
# 469/469 - 2s - loss: 0.1210 - 2s/epoch - 5ms/step
# Epoch 74/100
# 469/469 - 2s - loss: 0.1205 - 2s/epoch - 5ms/step
# Epoch 75/100
# 469/469 - 2s - loss: 0.1200 - 2s/epoch - 5ms/step
# Epoch 76/100
# 469/469 - 2s - loss: 0.1195 - 2s/epoch - 5ms/step
# Epoch 77/100
# 469/469 - 2s - loss: 0.1190 - 2s/epoch - 5ms/step
# Epoch 78/100
# 469/469 - 2s - loss: 0.1185 - 2s/epoch - 5ms/step
# Epoch 79/100
# 469/469 - 2s - loss: 0.1181 - 2s/epoch - 5ms/step
# Epoch 80/100
# 469/469 - 2s - loss: 0.1176 - 2s/epoch - 5ms/step
# Epoch 81/100
# 469/469 - 2s - loss: 0.1172 - 2s/epoch - 5ms/step
# Epoch 82/100
# 469/469 - 2s - loss: 0.1168 - 2s/epoch - 5ms/step
# Epoch 83/100
# 469/469 - 2s - loss: 0.1163 - 2s/epoch - 5ms/step
# Epoch 84/100
# 469/469 - 2s - loss: 0.1159 - 2s/epoch - 5ms/step
# Epoch 85/100
# 469/469 - 2s - loss: 0.1155 - 2s/epoch - 5ms/step
# Epoch 86/100
# 469/469 - 2s - loss: 0.1151 - 2s/epoch - 5ms/step
# Epoch 87/100
# 469/469 - 2s - loss: 0.1147 - 2s/epoch - 5ms/step
# Epoch 88/100
# 469/469 - 2s - loss: 0.1143 - 2s/epoch - 5ms/step
# Epoch 89/100
# 469/469 - 2s - loss: 0.1140 - 2s/epoch - 5ms/step
# Epoch 90/100
# 469/469 - 2s - loss: 0.1136 - 2s/epoch - 5ms/step
# Epoch 91/100
# 469/469 - 2s - loss: 0.1133 - 2s/epoch - 5ms/step
# Epoch 92/100
# 469/469 - 3s - loss: 0.1129 - 3s/epoch - 5ms/step
# Epoch 93/100
# 469/469 - 2s - loss: 0.1126 - 2s/epoch - 5ms/step
# Epoch 94/100
# 469/469 - 2s - loss: 0.1123 - 2s/epoch - 5ms/step
# Epoch 95/100
# 469/469 - 2s - loss: 0.1120 - 2s/epoch - 5ms/step
# Epoch 96/100
# 469/469 - 2s - loss: 0.1117 - 2s/epoch - 5ms/step
# Epoch 97/100
# 469/469 - 2s - loss: 0.1114 - 2s/epoch - 5ms/step
# Epoch 98/100
# 469/469 - 2s - loss: 0.1111 - 2s/epoch - 5ms/step
# Epoch 99/100
# 469/469 - 2s - loss: 0.1108 - 2s/epoch - 5ms/step
# Epoch 100/100
# 469/469 - 2s - loss: 0.1105 - 2s/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_images_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
