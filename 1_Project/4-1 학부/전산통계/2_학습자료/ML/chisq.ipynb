# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
table = [[388, 378], [196, 237], [25, 26]]
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)
print(stat, p)
# Out:
# dof=2
# [[373.1952 392.8048]
#  [210.9576 222.0424]
#  [ 24.8472  26.1528]]
# 3.215280402243019 0.20035986563286098
